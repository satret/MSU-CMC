# %%
# !nvidia-smi
# Out:
# Sun Nov  2 22:41:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.57                 Driver Version: 581.57         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070 Ti   WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   57C    P2             61W /  290W |    7684MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1700    C+G   C:\Windows\System32\dwm.exe           N/A      |
# |    0   N/A  N/A            2072    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A            4828    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A            4960    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A            6456    C+G   ....0.3537.99\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            7312    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A            7424    C+G   ...webinar-electron\MTS Link.exe      N/A      |
# |    0   N/A  N/A            8364    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A            8512    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A            8576      C   ...s\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A            8588    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A            9372    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A            9380    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10852      C   ...s\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A           11016    C+G   ....0.3537.99\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           11296    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           12760    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           13732    C+G   ...cord\app-1.0.9213\Discord.exe      N/A      |
# |    0   N/A  N/A           14596    C+G   ...s (x86)\v2RayTun\v2RayTun.exe      N/A      |
# |    0   N/A  N/A           15808    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           16136      C   ...s\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A           16716    C+G   ...Telegram Desktop\Telegram.exe      N/A      |
# |    0   N/A  N/A           17288      C   ...s\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A           17476      C   ...s\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A           18068    C+G   ...ef.win7x64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           20640      C   ...s\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A           21432      C   ...s\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A           22156      C   ...s\Python\Python310\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
import torch._dynamo
torch.set_float32_matmul_precision('high')
torch._dynamo.config.suppress_errors = True
torch._dynamo.disable()
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, GenerationConfig
from tqdm import tqdm
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, accuracy_score
import warnings
warnings.filterwarnings("ignore")

# %%
dataset_name = "Aniemore/cedr-m7"
dataset = load_dataset(dataset_name, split="test[:500]")
dataset
# Out:
# Dataset({
#     features: ['text', 'labels', 'source', 'label2ids'],
#     num_rows: 500
# })

# %%
df = pd.DataFrame(dataset)

if isinstance(df['labels'].iloc[0], list):
    label_names = df['labels'].explode().unique()
else:
    label_names = df['labels'].unique()

print(label_names)
# Out:
# ['neutral' 'fear' 'enthusiasm' 'sadness' 'happiness' 'anger' 'disgust']

# %%
labels_str = ", ".join(label_names)

# %%
def sample2messages(sample):
    text = sample['text']
    prompt = f"""Определи эмоцию в следующем тексте.
Текст: "{text}"
Эмоция (выбери только одно из: {labels_str}):"""
    return [{'role': 'user', 'content': prompt}]

# %%
warnings.filterwarnings("ignore")
model_names = ["Lamapi/next-1b", "Unbabel/Tower-Plus-2B"]
results = {}

for model_name in model_names:
    
    model = AutoModelForCausalLM.from_pretrained(
        model_name,  
        device_map='cuda', 
        torch_dtype=torch.bfloat16 
    )
    model.eval()

    tokenizer = AutoTokenizer.from_pretrained(model_name)

    gen_config = GenerationConfig.from_pretrained(model_name)
    gen_config.max_new_tokens = 15
    gen_config.do_sample = False
    gen_config.pad_token_id = tokenizer.eos_token_id

    def generate(sample):
        inputs = tokenizer.apply_chat_template(
            sample2messages(sample), 
            add_generation_prompt=True, 
            return_tensors='pt'
        )
        inputs = inputs.to(model.device)
        
        with torch.no_grad():
            res = model.generate(inputs, generation_config=gen_config).detach().cpu().numpy()[0]
        
        output_tokens = res[inputs.shape[1]:]
        return tokenizer.decode(output_tokens, skip_special_tokens=True)
    
    predictions = []
    ground_truth = []

    for sample in tqdm(dataset):
        predict_raw = generate(sample)
        
        predict_clean = predict_raw.strip().lower().strip(".,'\"")
        
        found_label = None
        for label in label_names:
            if label in predict_clean.split():
                found_label = label
                break
        
        if not found_label:
             for label in label_names:
                if label in predict_clean:
                    found_label = label
                    break
        
        if found_label is None:
            found_label = "unknown"
            
        predictions.append(found_label)
        
        true_label_str = sample['labels'][0].lower() 
        
        ground_truth.append(true_label_str)

    
    print(f"Результаты для {model_name}")
    
    report = classification_report(
        ground_truth, 
        predictions, 
        labels=label_names, 
        zero_division=0,
        digits=3
    )
    print(report)
    
    acc = accuracy_score(ground_truth, predictions)
    print(f"Overall Accuracy: {acc:.4f}")
    
    results[model_name] = {
        "report": report,
        "accuracy": acc
    }
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [08:59<00:00,  1.08s/it]
# Результаты для Lamapi/next-1b
#               precision    recall  f1-score   support
#
#      neutral      0.667     0.009     0.017       226
#         fear      0.812     0.703     0.754        37
#   enthusiasm      0.087     0.344     0.139        32
#      sadness      0.750     0.400     0.522       105
#    happiness      0.375     0.481     0.422        81
#        anger      0.128     0.882     0.224        17
#      disgust      0.000     0.000     0.000         2
#
#    micro avg      0.291     0.270     0.280       500
#    macro avg      0.403     0.403     0.297       500
# weighted avg      0.590     0.270     0.258       500
#
# Overall Accuracy: 0.2700
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
import torch
import torch._dynamo
torch.set_float32_matmul_precision('high')
torch._dynamo.config.suppress_errors = True
torch._dynamo.disable()
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, GenerationConfig
from tqdm import tqdm
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, accuracy_score
import warnings
warnings.filterwarnings("ignore")

model_name = "Unbabel/Tower-Plus-2B"
results = {}

model = AutoModelForCausalLM.from_pretrained(
    model_name,  
    device_map='cuda', 
    torch_dtype=torch.bfloat16 
)
model.eval()

tokenizer = AutoTokenizer.from_pretrained(model_name)

gen_config = GenerationConfig.from_pretrained(model_name)
gen_config.max_new_tokens = 15
gen_config.do_sample = False
gen_config.pad_token_id = tokenizer.eos_token_id

def generate(sample):
    inputs = tokenizer.apply_chat_template(
        sample2messages(sample), 
        add_generation_prompt=True, 
        return_tensors='pt'
    )
    inputs = inputs.to(model.device)
    
    with torch.no_grad():
        res = model.generate(inputs, generation_config=gen_config).detach().cpu().numpy()[0]
    
    output_tokens = res[inputs.shape[1]:]
    return tokenizer.decode(output_tokens, skip_special_tokens=True)

predictions = []
ground_truth = []

for sample in tqdm(dataset):
    predict_raw = generate(sample)
    
    predict_clean = predict_raw.strip().lower().strip(".,'\"")
    
    found_label = None
    for label in label_names:
        if label in predict_clean.split():
            found_label = label
            break
    
    if not found_label:
         for label in label_names:
            if label in predict_clean:
                found_label = label
                break
    
    if found_label is None:
        found_label = "unknown"
        
    predictions.append(found_label)
    
    true_label_str = sample['labels'][0].lower() 
    
    ground_truth.append(true_label_str)

print(f"Результаты для {model_name}")

report = classification_report(
    ground_truth, 
    predictions, 
    labels=label_names, 
    zero_division=0,
    digits=3
)
print(report)

acc = accuracy_score(ground_truth, predictions)
print(f"Overall Accuracy: {acc:.4f}")

results[model_name] = {
    "report": report,
    "accuracy": acc
}
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|                                                                                          | 0/500 [00:00<?, ?it/s]The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Using `cache_implementation='hybrid' is deprecated. Please only use one of ('static', 'offloaded_static'), and the layer structure will be inferred automatically.
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT wrapper C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\generic.py line 912
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py", line 2234, in __call__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1253, in compile_fx
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\contextlib.py", line 79, in inner
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return func(*args, **kwds)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py", line 2234, in __call__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1253, in compile_fx
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\contextlib.py", line 79, in inner
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return func(*args, **kwds)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1102 23:03:18.794000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT forward C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\gemma2\modeling_gemma2.py line 509
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py", line 2234, in __call__
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1253, in compile_fx
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\contextlib.py", line 79, in inner
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return func(*args, **kwds)
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W1102 23:03:38.046000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# ...
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\contextlib.py", line 79, in inner
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return func(*args, **kwds)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]   File "C:\Users\artur\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1102 23:04:22.636000 14784 site-packages\torch\_dynamo\convert_frame.py:1125]
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [21:32<00:00,  2.58s/it]
# Результаты для Unbabel/Tower-Plus-2B
#               precision    recall  f1-score   support
#
#      neutral      0.752     0.482     0.588       226
#         fear      0.337     0.919     0.493        37
#   enthusiasm      0.098     0.156     0.120        32
#      sadness      0.892     0.629     0.737       105
#    happiness      0.833     0.556     0.667        81
#        anger      0.192     0.824     0.311        17
#      disgust      0.000     0.000     0.000         2
#
#    micro avg      0.548     0.546     0.547       500
#    macro avg      0.443     0.509     0.417       500
# weighted avg      0.700     0.546     0.583       500
#
# Overall Accuracy: 0.5460
